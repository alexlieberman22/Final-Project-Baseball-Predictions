# %%
import pandas as pd
import numpy as np

# %%
ranking_data = pd.read_csv("../resources/ranking.csv")
ranking_data.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM  \
# 0  1610612756          0      22021    2022-03-12       West       Phoenix
# 1  1610612744          0      22021    2022-03-12       West  Golden State
# 2  1610612763          0      22021    2022-03-12       West       Memphis
# 3  1610612762          0      22021    2022-03-12       West          Utah
# 4  1610612742          0      22021    2022-03-12       West        Dallas
#
#     G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  67  53  14  0.791        28-8        25-6           NaN
# 1  68  46  22  0.676        28-7       18-15           NaN
# 2  68  46  22  0.676       24-10       22-12           NaN
# 3  67  42  25  0.627       24-10       18-15           NaN
# 4  67  41  26  0.612       23-12       18-14           NaN

# %%
ranking_df = ranking_data.copy()

# %%
ranking_df.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM  \
# 0  1610612756          0      22021    2022-03-12       West       Phoenix
# 1  1610612744          0      22021    2022-03-12       West  Golden State
# 2  1610612763          0      22021    2022-03-12       West       Memphis
# 3  1610612762          0      22021    2022-03-12       West          Utah
# 4  1610612742          0      22021    2022-03-12       West        Dallas
#
#     G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  67  53  14  0.791        28-8        25-6           NaN
# 1  68  46  22  0.676        28-7       18-15           NaN
# 2  68  46  22  0.676       24-10       22-12           NaN
# 3  67  42  25  0.627       24-10       18-15           NaN
# 4  67  41  26  0.612       23-12       18-14           NaN

# %%
ranking_df.dtypes
# Out:
# TEAM_ID            int64
# LEAGUE_ID          int64
# SEASON_ID          int64
# STANDINGSDATE     object
# CONFERENCE        object
# TEAM              object
# G                  int64
# W                  int64
# L                  int64
# W_PCT            float64
# HOME_RECORD       object
# ROAD_RECORD       object
# RETURNTOPLAY     float64
# dtype: object

# %%
ranking_df["STANDINGSDATE"] = pd.to_datetime(ranking_df["STANDINGSDATE"])

# %%
ranking_df.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM  \
# 0  1610612756          0      22021    2022-03-12       West       Phoenix
# 1  1610612744          0      22021    2022-03-12       West  Golden State
# 2  1610612763          0      22021    2022-03-12       West       Memphis
# 3  1610612762          0      22021    2022-03-12       West          Utah
# 4  1610612742          0      22021    2022-03-12       West        Dallas
#
#     G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  67  53  14  0.791        28-8        25-6           NaN
# 1  68  46  22  0.676        28-7       18-15           NaN
# 2  68  46  22  0.676       24-10       22-12           NaN
# 3  67  42  25  0.627       24-10       18-15           NaN
# 4  67  41  26  0.612       23-12       18-14           NaN

# %%
ranking_df["LEAGUE_ID"].value_counts()
# Out:
# 0    201792
# Name: LEAGUE_ID, dtype: int64

# %%
ranking_df = ranking_df.drop(["LEAGUE_ID"], axis = 1)

# %%
ranking_df.head(10)
# Out:
#       TEAM_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM   G   W   L  \
# 0  1610612756      22021    2022-03-12       West       Phoenix  67  53  14
# 1  1610612744      22021    2022-03-12       West  Golden State  68  46  22
# 2  1610612763      22021    2022-03-12       West       Memphis  68  46  22
# 3  1610612762      22021    2022-03-12       West          Utah  67  42  25
# 4  1610612742      22021    2022-03-12       West        Dallas  67  41  26
# 5  1610612743      22021    2022-03-12       West        Denver  68  40  28
# 6  1610612750      22021    2022-03-12       West     Minnesota  69  39  30
# 7  1610612746      22021    2022-03-12       West   LA Clippers  69  35  34
# 8  1610612747      22021    2022-03-12       West   L.A. Lakers  66  29  37
# 9  1610612740      22021    2022-03-12       West   New Orleans  67  27  40
#
#    W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  0.791        28-8        25-6           NaN
# ...

# %%
ranking_df.dtypes
# Out:
# TEAM_ID                   int64
# SEASON_ID                 int64
# STANDINGSDATE    datetime64[ns]
# CONFERENCE               object
# TEAM                     object
# G                         int64
# W                         int64
# L                         int64
# W_PCT                   float64
# HOME_RECORD              object
# ROAD_RECORD              object
# RETURNTOPLAY            float64
# dtype: object

# %%
len(ranking_df)
# Out:
# 201792

# %%
ranking_df["RETURNTOPLAY"].value_counts()
# Out:
# 1.0    2394
# 0.0    1596
# Name: RETURNTOPLAY, dtype: int64

# %%
ranking_df = ranking_df.drop(["RETURNTOPLAY"], axis = 1)
ranking_df.head(10)
# Out:
#       TEAM_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM   G   W   L  \
# 0  1610612756      22021    2022-03-12       West       Phoenix  67  53  14
# 1  1610612744      22021    2022-03-12       West  Golden State  68  46  22
# 2  1610612763      22021    2022-03-12       West       Memphis  68  46  22
# 3  1610612762      22021    2022-03-12       West          Utah  67  42  25
# 4  1610612742      22021    2022-03-12       West        Dallas  67  41  26
# 5  1610612743      22021    2022-03-12       West        Denver  68  40  28
# 6  1610612750      22021    2022-03-12       West     Minnesota  69  39  30
# 7  1610612746      22021    2022-03-12       West   LA Clippers  69  35  34
# 8  1610612747      22021    2022-03-12       West   L.A. Lakers  66  29  37
# 9  1610612740      22021    2022-03-12       West   New Orleans  67  27  40
#
#    W_PCT HOME_RECORD ROAD_RECORD
# 0  0.791        28-8        25-6
# 1  0.676        28-7       18-15
# ...

# %%
ranking_df["SEASON_ID"].value_counts()
# Out:
# 22010    12480
# 22019    12240
# 22018    10470
# 22017    10380
# 22004    10260
# 22009    10230
# 22007    10230
# 22012    10200
# 22015    10200
# 22006    10200
# 22013    10200
# 22016    10200
# 22014    10170
# 22003    10150
# 22005    10140
# 22008    10140
# 22020     8573
# 22011     8550
# 22021     4350
# 12019      900
# 12006      780
# 12009      780
# 12012      750
# 12015      750
# 12016      720
# 12007      720
# 12013      720
# 12014      720
# 12008      690
# 12010      690
# 12003      667
# 12005      660
# 12004      630
# 12018      540
# 12017      510
# 12021      480
# 12020      336
# 12011      270
# 22002      116
# Name: SEASON_ID, dtype: int64

# %%
len(ranking_df)
# Out:
# 201792
